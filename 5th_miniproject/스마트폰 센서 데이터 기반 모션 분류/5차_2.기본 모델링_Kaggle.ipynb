# %% [markdown]
# #**스마트폰 센서 데이터 기반 모션 분류**
# # 단계2 : 기본 모델링

# %% [markdown]
# ## 0.미션

# %% [markdown]
# * 데이터 전처리
#     * 가변수화, 데이터 분할, NaN 확인 및 조치, 스케일링 등 필요한 전처리 수행
# * 다양한 알고리즘으로 분류 모델 생성
#     * 최소 4개 이상의 알고리즘을 적용하여 모델링 수행
#     * 성능 비교
#     * 각 모델의 성능을 저장하는 별도 데이터 프레임을 만들고 비교
# * 옵션 : 다음 사항은 선택사항입니다. 시간이 허용하는 범위 내에서 수행하세요.
#     * 상위 N개 변수를 선정하여 모델링 및 성능 비교
#         * 모델링에 항상 모든 변수가 필요한 것은 아닙니다.
#         * 변수 중요도 상위 N개를 선정하여 모델링하고 타 모델과 성능을 비교하세요.
#         * 상위 N개를 선택하는 방법은, 변수를 하나씩 늘려가며 모델링 및 성능 검증을 수행하여 적절한 지점을 찾는 것입니다.

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# ### (1) 라이브러리 불러오기

# %% [markdown]
# * 세부 요구사항
#     - 기본적으로 필요한 라이브러리를 import 하도록 코드가 작성되어 있습니다.
#     - 필요하다고 판단되는 라이브러리를 추가하세요.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 필요하다고 판단되는 라이브러리를 추가하세요.
import os
from sklearn.model_selection import train_test_split
import joblib
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import *
from sklearn.inspection import permutation_importance
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# * 함수 생성

# %%
# 변수의 특성 중요도 계산하기
def plot_feature_importance(importance, names, result_only = False, topn = 'all'):
    feature_importance = np.array(importance)
    feature_name = np.array(names)

    data={'feature_name':feature_name,'feature_importance':feature_importance}
    fi_temp = pd.DataFrame(data)

    #변수의 특성 중요도 순으로 정렬하기
    fi_temp.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    fi_temp.reset_index(drop=True, inplace = True)

    if topn == 'all' :
        fi_df = fi_temp.copy()
    else :
        fi_df = fi_temp.iloc[:topn]

    #변수의 특성 중요도 그래프로 그리기
    if result_only == False :
        plt.figure(figsize=(10,20))
        sns.barplot(x='feature_importance', y='feature_name', data = fi_df)

        plt.xlabel('importance')
        plt.ylabel('feature name')
        plt.grid()

    return fi_df

# %% [markdown]
# ### (2) 데이터 불러오기

# %% [markdown]
# * 주어진 데이터셋
#     * data01_train.csv : 학습 및 검증용
# * 세부 요구사항
#     - 전체 데이터 'data01_train.csv' 를 불러와 'data' 이름으로 저장합니다.
#         - data에서 변수 subject는 삭제합니다.
#     - 데이터프레임에 대한 기본 정보를 확인합니다.( .head(), .shape 등)

# %% [markdown]
# #### 1) 데이터 로딩

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
FOLDER_PATH = '/content/drive/MyDrive/에이블/미니프로젝트5차_3~5일차/Kaggle'

data = pd.read_csv(os.path.join(FOLDER_PATH, 'data01_train.csv'))
print(data.shape)
# Out:
# (5881, 563)

# %%
importance_data = joblib.load(os.path.join(PATH, 'importance_data.pkl'))

# %%
data.drop('subject', axis=1, inplace=True)

# %% [markdown]
# #### 2) 기본 정보 조회

# %%
data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288508          -0.009196          -0.103362         -0.988986
# 1           0.265757          -0.016576          -0.098163         -0.989551
# 2           0.278709          -0.014511          -0.108717         -0.997720
# 3           0.289795          -0.035536          -0.150354         -0.231727
# 4           0.394807           0.034098           0.091229          0.088489
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.962797         -0.967422         -0.989000         -0.962596
# 1         -0.994636         -0.987435         -0.990189         -0.993870
# 2         -0.981088         -0.994008         -0.997934         -0.982187
# 3         -0.006412         -0.338117         -0.273557          0.014245
# 4         -0.106636         -0.388502         -0.010469         -0.109680
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-skewness()  \
# 0         -0.965650         -0.929747  ...                        -0.487737
# 1         -0.987558         -0.937337  ...                        -0.237820
# 2         -0.995017         -0.942584  ...                        -0.535287
# 3         -0.347916          0.008288  ...                        -0.004012
# 4         -0.346372          0.584131  ...                        -0.157832
#
#    fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                        -0.816696                    -0.042494
# 1                        -0.693515                    -0.062899
# 2                        -0.829311                     0.000265
# 3                        -0.408956                    -0.255125
# 4                        -0.563437                    -0.044344
#
#    angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                             -0.044218                          0.307873
# 1                              0.388459                         -0.765014
# 2                             -0.525022                         -0.891875
# 3                              0.612804                          0.747381
# 4                             -0.845268                         -0.974650
#
#    angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                              0.072790             -0.601120
# 1                              0.771524              0.345205
# 2                              0.021528             -0.833564
# 3                             -0.072944             -0.695819
# 4                             -0.887846             -0.705029
#
#    angle(Y,gravityMean)  angle(Z,gravityMean)            Activity
# 0              0.331298              0.165163            STANDING
# 1             -0.769186             -0.147944              LAYING
# 2              0.202434             -0.032755            STANDING
# 3              0.287154              0.111388             WALKING
# 4              0.264952              0.137758  WALKING_DOWNSTAIRS
#
# [5 rows x 562 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5881 entries, 0 to 5880
# Columns: 562 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), object(1)
# memory usage: 25.2+ MB

# %%
nan_counts = data.isna().sum()

# 0 초과인 값이 있는 인덱스를 출력
indexes_with_nulls = np.where(nan_counts > 0)[0]

print("결측치가 있는 열의 인덱스:", indexes_with_nulls)
# Out:
# 결측치가 있는 열의 인덱스: []

# %%
 importance_data.head(2)
# Out:
#         feature_name  total_feature_importance  dynamic_feature_importance  \
# 0  tBodyAcc-mean()-X                  0.000245                    0.000009
# 1  tBodyAcc-mean()-Y                  0.000217                    0.000017
#
#    standing_feature_importance  sitting_feature_importance  \
# 0                     0.000216                    0.000329
# 1                     0.000492                    0.000365
#
#    laying_feature_importance  walking_feature_importance  \
# 0                   0.000709                    0.000169
# 1                   0.000090                    0.000241
#
#    walking_up_feature_importance  walking_down_feature_importance
# 0                       0.000116                         0.000066
# 1                       0.001091                         0.000380

# %%
importance_data.drop(['sensor', 'agg', 'axis'], axis=1, inplace=True)

# %% [markdown]
# ## **2. 데이터 전처리**
#
# * 가변수화, 데이터 분할, NaN 확인 및 조치, 스케일링 등 필요한 전처리를 수행한다.

# %% [markdown]
# ### (1) 데이터 분할1 : x, y

# %% [markdown]
# * 세부 요구사항
#     - x, y로 분할합니다.

# %%
target = 'Activity'

x = data.drop(columns=target, axis=1)
y = data[target]

# %% [markdown]
# ### (2) 스케일링(필요시)

# %% [markdown]
# * 세부 요구사항
#     - 스케일링을 필요로 하는 알고리즘 사용을 위해서 코드 수행
#     - min-max 방식 혹은 standard 방식 중 한가지 사용.

# %%
scaler = MinMaxScaler()
x_train_s = scaler.fit_transform(x_train)
x_val_s = scaler.transform(x_val)

# %%
# scaler = StandardScaler()
# x_train_s = scaler.fit_transform(x_train)
# x_val_s = scaler.transform(x_val)

# %% [markdown]
# * 라벨 인코더

# %%
from sklearn.preprocessing import LabelEncoder

# LabelEncoder 객체 생성
label_encoder = LabelEncoder()

# 학습 데이터와 검증 데이터의 레이블을 변환
y_train_l = label_encoder.fit_transform(y_train)
y_val_l = label_encoder.transform(y_val)

# %% [markdown]
# ### (3) 데이터분할2 : train, validation

# %% [markdown]
# * 세부 요구사항
#     - train : val = 8 : 2 혹은 7 : 3
#     - random_state 옵션을 사용하여 다른 모델과 비교를 위해 성능이 재현되도록 합니다.

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## **3. 기본 모델링**

# %% [markdown]
# * 세부 요구사항
#     - 최소 4개 이상의 알고리즘을 적용하여 모델링을 수행한다.
#     - 각 알고리즘별로 전체 변수로 모델링, 상위 N(20)개 변수를 선택하여 모델링을 수행하고 성능 비교를 한다.
#     - (옵션) 알고리즘 중 1~2개에 대해서, 변수 중요도 상위 N(20)개를 선정하여 모델링하고 타 모델과 성능을 비교.
#         * 상위 N개를 선택하는 방법은, 변수를 하나씩 늘려가며 모델링 및 성능 검증을 수행하여 적절한 지점을 찾는 것이다.

# %%
def plot_feature_importance(importance, names, topn = 'all'):   # topn = 'all'
    feature_importance = np.array(importance)
    feature_names = np.array(names)

    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_temp = pd.DataFrame(data)

    fi_temp.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    fi_temp.reset_index(drop=True, inplace = True)

    if topn == 'all' :
        fi_df = fi_temp.copy()
    # else :
    #     fi_df = fi_temp.iloc[:topn]

    # plt.figure(figsize=(10,8))
    # sns.barplot(x='feature_importance', y='feature_names', data = fi_df)

    # plt.xlabel('importance')
    # plt.ylabel('feature names')
    # plt.grid()

    return fi_df

# %% [markdown]
# ### (1) 알고리즘1 : KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier()
model.fit(x_train_s, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = model.predict(x_val_s)
print(accuracy_score(y_val, y_pred))
print(classification_report(y_val, y_pred))
# Out:
# 0.9634664401019541
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       231
#            SITTING       0.92      0.87      0.89       200
#           STANDING       0.89      0.94      0.92       226
#            WALKING       0.99      1.00      1.00       198
# WALKING_DOWNSTAIRS       1.00      0.99      0.99       145
#   WALKING_UPSTAIRS       0.99      1.00      1.00       177
#
#           accuracy                           0.96      1177
#          macro avg       0.97      0.96      0.97      1177
#       weighted avg       0.96      0.96      0.96      1177

# %%
from sklearn.inspection import permutation_importance
pfi = permutation_importance(model, x_val_s, y_val, n_repeats=1, scoring = 'accuracy', random_state=42)

# %%
fi = plot_feature_importance(pfi.importances_mean, list(x))

# %%
len(list(x_train))
# Out:
# 561

# %%
if isinstance(list(x_train_s), np.ndarray):
    print("pfi.importances_mean is a NumPy array.")
else:
    print("pfi.importances_mean is not a NumPy array.")
# Out:
# pfi.importances_mean is not a NumPy array.

# %%
pfi
# Out:
# {'importances_mean': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  5.66411781e-04,
#         -2.83205891e-04,  5.66411781e-04,  5.66411781e-04, -2.83205891e-04,
#          5.66411781e-04,  1.13282356e-03, -2.83205891e-04, -2.83205891e-04,
#          2.83205891e-04, -2.83205891e-04,  8.49617672e-04,  2.83205891e-04,
#          5.66411781e-04,  0.00000000e+00, -2.83205891e-04,  8.49617672e-04,
#          3.70074342e-17,  2.83205891e-04, -5.66411781e-04, -8.49617672e-04,
#         -1.13282356e-03, -2.26564713e-03, -1.69923534e-03, -2.83205891e-04,
#         -1.13282356e-03, -5.66411781e-04, -5.66411781e-04,  7.40148683e-17,
#         -8.49617672e-04,  1.41602945e-03,  8.49617672e-04,  0.00000000e+00,
#          2.83205891e-04,  5.66411781e-04,  1.41602945e-03, -1.41602945e-03,
#          0.00000000e+00,  5.66411781e-04,  2.83205891e-04,  0.00000000e+00,
#          0.00000000e+00, -8.49617672e-04,  0.00000000e+00,  0.00000000e+00,
#         -5.66411781e-04,  0.00000000e+00,  1.13282356e-03,  3.70074342e-17,
#          0.00000000e+00,  2.83205891e-04, -2.83205891e-04,  8.49617672e-04,
#         -2.83205891e-04,  3.70074342e-17,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1

    cols = fi['feature_names'].values[:i]
    temp_x = x_train[cols]
    rf = KNeighborsClassifier()
    rf.fit(temp_x, y_train)
    print(f"{i} : {rf.score(x_val[cols], y_val)}")
# Out:
# 20 : 0.8742565845369583
# 30 : 0.9048428207306712
# 40 : 0.9167374681393373
# 50 : 0.929481733220051
# 60 : 0.923534409515718
# 70 : 0.9405267629566695
# 80 : 0.9379779099405268
# 90 : 0.945624468988955
# 100 : 0.945624468988955
# 110 : 0.945624468988955
# 120 : 0.9464740866610025

# %% [markdown]
# ### (2) 알고리즘2 : Logistic

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(x_train_s, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(x_val_s)
print(accuracy_score(y_val, y_pred))
print(classification_report(y_val, y_pred))
# Out:
# 0.9881053525913339
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       231
#            SITTING       0.95      0.99      0.97       200
#           STANDING       0.99      0.96      0.97       226
#            WALKING       1.00      0.99      1.00       198
# WALKING_DOWNSTAIRS       1.00      0.99      1.00       145
#   WALKING_UPSTAIRS       0.99      1.00      0.99       177
#
#           accuracy                           0.99      1177
#          macro avg       0.99      0.99      0.99      1177
#       weighted avg       0.99      0.99      0.99      1177

# %%
from sklearn.inspection import permutation_importance
pfi = permutation_importance(model, x_val_s, y_val, n_repeats=3, scoring = 'accuracy', random_state=42)
fi = plot_feature_importance(pfi.importances_mean, list(x_train_s))

# %% [markdown]
# ### (3) 알고리즘3 : XgbBoost

# %%
from xgboost import XGBClassifier

model = XGBClassifier()
model.fit(x_train, y_train_l)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
y_pred = model.predict(x_val)
print(accuracy_score(y_val_l, y_pred))
print(classification_report(y_val_l, y_pred))
# Out:
# 0.9923534409515717
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       231
#            1       0.98      0.99      0.99       200
#            2       1.00      0.98      0.99       226
#            3       0.99      0.98      0.99       198
#            4       0.99      0.99      0.99       145
#            5       0.99      1.00      0.99       177
#
#     accuracy                           0.99      1177
#    macro avg       0.99      0.99      0.99      1177
# weighted avg       0.99      0.99      0.99      1177

# %%
fi = plot_feature_importance(model.feature_importances_, list(x_train))
for i in range(20, 121, 10):
    cols = fi['feature_names'].values[:i]
    temp_x = x_train[cols]
    rf = XGBClassifier()
    rf.fit(temp_x, y_train)
    print(f"{i} : {rf.score(x_val[cols], y_val)}")
# Out:
# 20 : 0.9600679694137638
# 30 : 0.9600679694137638
# 40 : 0.9617672047578589
# 50 : 0.9566694987255735
# 60 : 0.9583687340696686
# 70 : 0.9549702633814783
# 80 : 0.9549702633814783
# 90 : 0.9719626168224299
# 100 : 0.9668649107901445
# 110 : 0.9643160577740016
# 120 : 0.973661852166525

# %% [markdown]
# ### (4) 알고리즘4 : SVM

# %%
from sklearn.svm import SVC

model = SVC()
model.fit(x_train_s, y_train)
# Out:
# SVC()

# %%
y_pred = model.predict(x_val_s)
print(accuracy_score(y_val, y_pred))
print(classification_report(y_val, y_pred))
# Out:
# 0.9787595581988106
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       231
#            SITTING       0.92      0.97      0.94       200
#           STANDING       0.98      0.92      0.95       226
#            WALKING       1.00      0.99      1.00       198
# WALKING_DOWNSTAIRS       1.00      0.99      1.00       145
#   WALKING_UPSTAIRS       0.99      1.00      0.99       177
#
#           accuracy                           0.98      1177
#          macro avg       0.98      0.98      0.98      1177
#       weighted avg       0.98      0.98      0.98      1177

# %%
from sklearn.inspection import permutation_importance
pfi = permutation_importance(model, x_val_s, y_val, n_repeats=3, scoring = 'accuracy', random_state=42)
fi = plot_feature_importance(pfi.importances_mean, list(x_train_s))

# %% [markdown]
# ### (5) 알고리즘5 : Randomforest

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(x_val)
print(accuracy_score(y_val, y_pred))
print(classification_report(y_val, y_pred))
# Out:
# 0.9804587935429057
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       231
#            SITTING       0.96      0.98      0.97       200
#           STANDING       0.98      0.96      0.97       226
#            WALKING       0.98      0.98      0.98       198
# WALKING_DOWNSTAIRS       0.97      0.97      0.97       145
#   WALKING_UPSTAIRS       0.98      0.98      0.98       177
#
#           accuracy                           0.98      1177
#          macro avg       0.98      0.98      0.98      1177
#       weighted avg       0.98      0.98      0.98      1177

# %%
fi = plot_feature_importance(model.feature_importances_, list(x_train))
for i in range(20, 121, 10):
    cols = fi['feature_names'].values[:i]
    temp_x = x_train[cols]
    rf = KNeighborsClassifier()
    rf.fit(temp_x, y_train)
    print(f"{i} : {rf.score(x_val[cols], y_val)}")
# Out:
# 20 : 0.9592183517417162
# 30 : 0.9575191163976211
# 40 : 0.9592183517417162
# 50 : 0.9575191163976211
# 60 : 0.9541206457094308
# 70 : 0.9507221750212405
# 80 : 0.9566694987255735
# 90 : 0.9626168224299065
# 100 : 0.9592183517417162
# 110 : 0.9566694987255735
# 120 : 0.9549702633814783

# %% [markdown]
# ### (6) 딥러닝

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout, Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

# %%
model = Sequential([
    Input(shape=(x_train_s.shape[1])),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(6, activation='softmax'),
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 128)               71936
#
#  batch_normalization_6 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 128)               16512
#
#  batch_normalization_7 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 128)               16512
#
#  batch_normalization_8 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 107270 (419.02 KB)
# Trainable params: 106502 (416.02 KB)
# Non-trainable params: 768 (3.00 KB)
# _________________________________________________________________

# %%
es = EarlyStopping(monitor='val_loss', patience=10, min_delta=0, verbose=1, restore_best_weights=True)

model.fit(x_train_s, y_train_l, verbose=1, epochs=30, callbacks=[es], validation_split=0.2)
# Out:
# Epoch 1/30
# 118/118 [==============================] - 3s 11ms/step - loss: 0.5694 - accuracy: 0.7824 - val_loss: 0.9625 - val_accuracy: 0.6440
# Epoch 2/30
# 118/118 [==============================] - 1s 9ms/step - loss: 0.2443 - accuracy: 0.9073 - val_loss: 0.3365 - val_accuracy: 0.8587
# Epoch 3/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.1921 - accuracy: 0.9309 - val_loss: 0.1760 - val_accuracy: 0.9214
# Epoch 4/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.1677 - accuracy: 0.9338 - val_loss: 0.1813 - val_accuracy: 0.9277
# Epoch 5/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.1400 - accuracy: 0.9458 - val_loss: 0.1830 - val_accuracy: 0.9362
# Epoch 6/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.1329 - accuracy: 0.9532 - val_loss: 0.1979 - val_accuracy: 0.9245
# Epoch 7/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.1117 - accuracy: 0.9593 - val_loss: 0.1692 - val_accuracy: 0.9373
# Epoch 8/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.1089 - accuracy: 0.9588 - val_loss: 0.0875 - val_accuracy: 0.9734
# Epoch 9/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.0988 - accuracy: 0.9631 - val_loss: 0.0914 - val_accuracy: 0.9617
# Epoch 10/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.0976 - accuracy: 0.9644 - val_loss: 0.0865 - val_accuracy: 0.9692
# Epoch 11/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.0891 - accuracy: 0.9697 - val_loss: 0.0980 - val_accuracy: 0.9596
# Epoch 12/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.0867 - accuracy: 0.9686 - val_loss: 0.1029 - val_accuracy: 0.9617
# Epoch 13/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.0801 - accuracy: 0.9681 - val_loss: 0.1705 - val_accuracy: 0.9330
# Epoch 14/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.0836 - accuracy: 0.9710 - val_loss: 0.1198 - val_accuracy: 0.9511
# Epoch 15/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.0816 - accuracy: 0.9689 - val_loss: 0.1427 - val_accuracy: 0.9522
# Epoch 16/30
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0924 - accuracy: 0.9678 - val_loss: 0.0777 - val_accuracy: 0.9713
# Epoch 17/30
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0746 - accuracy: 0.9729 - val_loss: 0.0786 - val_accuracy: 0.9713
# Epoch 18/30
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0942 - accuracy: 0.9673 - val_loss: 0.0912 - val_accuracy: 0.9724
# Epoch 19/30
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0733 - accuracy: 0.9708 - val_loss: 0.1702 - val_accuracy: 0.9373
# Epoch 20/30
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0632 - accuracy: 0.9748 - val_loss: 0.0752 - val_accuracy: 0.9745
# Epoch 21/30
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0721 - accuracy: 0.9713 - val_loss: 0.0664 - val_accuracy: 0.9745
# Epoch 22/30
# 118/118 [==============================] - 1s 6ms/step - loss: 0.0717 - accuracy: 0.9734 - val_loss: 0.0734 - val_accuracy: 0.9692
# Epoch 23/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.0581 - accuracy: 0.9766 - val_loss: 0.0572 - val_accuracy: 0.9798
# Epoch 24/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.0658 - accuracy: 0.9774 - val_loss: 0.0546 - val_accuracy: 0.9809
# Epoch 25/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.0653 - accuracy: 0.9782 - val_loss: 0.1424 - val_accuracy: 0.9426
# Epoch 26/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.0654 - accuracy: 0.9761 - val_loss: 0.0960 - val_accuracy: 0.9564
# Epoch 27/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.0677 - accuracy: 0.9737 - val_loss: 0.0700 - val_accuracy: 0.9756
# Epoch 28/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.0705 - accuracy: 0.9761 - val_loss: 0.0604 - val_accuracy: 0.9809
# Epoch 29/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.0581 - accuracy: 0.9785 - val_loss: 0.0526 - val_accuracy: 0.9798
# Epoch 30/30
# 118/118 [==============================] - 1s 5ms/step - loss: 0.0579 - accuracy: 0.9779 - val_loss: 0.0569 - val_accuracy: 0.9819

# %%
model.evaluate(x_val_s, y_val_l)
# Out:
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0431 - accuracy: 0.9847
# [0.04314330592751503, 0.9847068786621094]

# %% [markdown]
# ## **4. 기본 모델링(selected feature)**

# %% [markdown]
# * 세부 요구사항
#     - 최소 4개 이상의 알고리즘을 적용하여 모델링을 수행한다.
#     - 각 알고리즘별로 전체 변수로 모델링, 상위 N개 변수를 선택하여 모델링을 수행하고 성능 비교를 한다.
#     - (옵션) 알고리즘 중 1~2개에 대해서, 변수 중요도 상위 N개를 선정하여 모델링하고 타 모델과 성능을 비교.
#         * 상위 N개를 선택하는 방법은, 변수를 하나씩 늘려가며 모델링 및 성능 검증을 수행하여 적절한 지점을 찾는 것이다.

# %%
# 랜덤 50개 feature 추출
data.head()
# data_sel = data.sample(50,replace=False, axis=1, random_state=42, ignore_index=True) # random_state=2023
data_sel = data.sample(20,replace=False, axis=1, random_state=42, ignore_index=True)
data_sel['Activity'] = data['Activity']

# %%
data_sel
# Out:
#       fBodyAccJerk-bandsEnergy()-33,40.1  fBodyAcc-mad()-X  \
# 0                              -0.999937         -0.988021
# 1                              -0.999919         -0.988538
# 2                              -0.999543         -0.997419
# 3                              -0.901223         -0.146359
# 4                              -0.960068          0.105888
# ...                                  ...               ...
# 5876                           -0.999638         -0.993514
# 5877                           -0.822945          0.013892
# 5878                           -0.999893         -0.990401
# 5879                           -0.956153         -0.022763
# 5880                           -0.999364         -0.992294
#
#       fBodyGyro-meanFreq()-Y  fBodyAcc-min()-X  tBodyGyroJerk-arCoeff()-Y,1  \
# 0                  -0.535663         -0.983218                    -0.428046
# 1                  -0.446218         -0.995414                    -0.351409
# 2                   0.402094         -0.995747                     0.334204
# 3                  -0.185642         -0.697850                    -0.274961
# 4                  -0.282879          0.358459                    -0.380950
# ...                      ...               ...                          ...
# 5876               -0.610779         -0.996199                    -0.328224
# 5877               -0.622211         -0.617405                    -0.270950
# 5878                0.503339         -0.997246                     0.399783
# 5879               -0.195882         -0.521987                    -0.252746
# 5880                0.272075         -0.999006                    -0.022858
#
#       tBodyGyroMag-arCoeff()2  fBodyAcc-bandsEnergy()-1,8.1  \
# 0                    0.072201                     -0.998868
# 1                    0.035071                     -0.999959
# 2                   -0.491549                     -0.999827
# 3                   -0.361825                     -0.499990
# 4                    0.346127                     -0.560876
# ...                       ...                           ...
# 5876                 0.192051                     -0.996934
# 5877                 0.011222                     -0.713397
# 5878                -0.607265                     -0.999953
# 5879                -0.035405                     -0.423097
# 5880                 0.037198                     -0.953065
#
#       tBodyGyroJerkMag-min()  fBodyGyro-bandsEnergy()-57,64.2  \
# 0                  -0.988517                        -0.999698
# 1                  -0.993606                        -0.999989
# 2                  -0.990569                        -0.999993
# 3                  -0.603738                        -0.704933
# 4                  -0.878159                        -0.981072
# ...                      ...                              ...
# 5876               -0.972656                        -0.999989
# 5877               -0.746841                        -0.836757
# 5878               -0.984686                        -0.999958
# 5879               -0.834767                        -0.978726
# 5880               -0.984209                        -0.998450
#
#       fBodyAcc-energy()-Y  ...  tBodyGyroJerk-correlation()-X,Z  \
# 0               -0.998941  ...                         0.003330
# 1               -0.999932  ...                         0.229115
# 2               -0.999633  ...                        -0.237477
# 3               -0.501328  ...                        -0.126100
# 4               -0.595957  ...                         0.043063
# ...                   ...  ...                              ...
# 5876            -0.997655  ...                         0.058509
# 5877            -0.609367  ...                        -0.656106
# 5878            -0.999848  ...                         0.021914
# 5879            -0.441166  ...                        -0.216026
# 5880            -0.965820  ...                         0.344327
#
#       tBodyAcc-min()-Y  tGravityAcc-mean()-X  tBodyGyro-std()-Y  \
# 0             0.681264              0.875254          -0.968673
# 1             0.694376             -0.134711          -0.976701
# 2             0.681985              0.965965          -0.996322
# 3             0.067789              0.927343          -0.432211
# 4             0.135817              0.901125          -0.574059
# ...                ...                   ...                ...
# 5876          0.679860              0.973223          -0.970289
# 5877          0.304995              0.910932          -0.122764
# 5878          0.691052             -0.514220          -0.991982
# 5879          0.003324              0.921553          -0.494265
# 5880          0.624744              0.929064          -0.968550
#
#       tBodyAcc-arCoeff()-Y,2  tBodyAcc-arCoeff()-Z,1  tBodyGyroMag-std()  \
# 0                  -0.011862               -0.049915           -0.970071
# 1                  -0.311399                0.005108           -0.974138
# 2                  -0.173546                0.562884           -0.992006
# 3                   0.412219               -0.262981           -0.453516
# 4                   0.565149               -0.291032           -0.246889
# ...                      ...                     ...                 ...
# 5876               -0.107601                0.016549           -0.974275
# 5877                0.194360               -0.023946           -0.200862
# 5878               -0.231762                0.322018           -0.991276
# 5879                0.536557               -0.035675           -0.378939
# 5880               -0.039938                0.225627           -0.947434
#
#       fBodyAcc-bandsEnergy()-33,40  tBodyGyroMag-arCoeff()3  \
# 0                        -0.999775                 0.053967
# 1                        -0.999858                 0.377881
# 2                        -0.999986                 0.585057
# 3                        -0.824705                 0.278173
# 4                        -0.643314                -0.091558
# ...                            ...                      ...
# 5876                     -0.999863                -0.186759
# 5877                     -0.817577                 0.158229
# 5878                     -0.999830                 0.350757
# 5879                     -0.880905                 0.232269
# 5880                     -0.999824                 0.202347
#
#                 Activity
# 0               STANDING
# 1                 LAYING
# 2               STANDING
# 3                WALKING
# 4     WALKING_DOWNSTAIRS
# ...                  ...
# 5876             SITTING
# 5877    WALKING_UPSTAIRS
# 5878              LAYING
# 5879    WALKING_UPSTAIRS
# 5880             SITTING
#
# [5881 rows x 51 columns]

# %%
target = 'Activity'

x = data_sel.drop(columns=target, axis=1)
y = data_sel[target]

x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=42)

scaler = MinMaxScaler()
x_train_s = scaler.fit_transform(x_train)
x_val_s = scaler.transform(x_val)

# LabelEncoder 객체 생성
label_encoder = LabelEncoder()
# 학습 데이터와 검증 데이터의 레이블을 변환
y_train_l = label_encoder.fit_transform(y_train)
y_val_l = label_encoder.transform(y_val)

# %% [markdown]
# ### (1) 알고리즘1 : RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(x_train, y_train)

y_pred = model.predict(x_val)
print(accuracy_score(y_val, y_pred))
print(classification_report(y_val, y_pred))

fi = plot_feature_importance(model.feature_importances_, list(x_train))
for i in range(50, 301, 50):
    cols = fi['feature_names'].values[:i]
    temp_x = x_train[cols]
    rf = RandomForestClassifier()
    rf.fit(temp_x, y_train)
    print(f"{i} : {rf.score(x_val[cols], y_val)}")
# Out:
# 0.9770603228547153
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       231
#            SITTING       0.95      0.97      0.96       200
#           STANDING       0.97      0.95      0.96       226
#            WALKING       0.98      0.98      0.98       198
# WALKING_DOWNSTAIRS       0.97      0.97      0.97       145
#   WALKING_UPSTAIRS       0.98      0.98      0.98       177
#
#           accuracy                           0.98      1177
#          macro avg       0.98      0.98      0.98      1177
#       weighted avg       0.98      0.98      0.98      1177
#
# 50 : 0.9762107051826678
# 100 : 0.9847068819031436
# 150 : 0.9889549702633815
# 200 : 0.9813084112149533
# 250 : 0.9821580288870009
# 300 : 0.9821580288870009

# %%
# 변수 랜덤 50개 선택
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(x_train, y_train)

y_pred = model.predict(x_val)
print(accuracy_score(y_val, y_pred))
print(classification_report(y_val, y_pred))
# Out:
# 0.8232795242141037
#                     precision    recall  f1-score   support
#
#             LAYING       0.78      0.84      0.81       231
#            SITTING       0.72      0.64      0.68       200
#           STANDING       0.74      0.75      0.75       226
#            WALKING       0.89      0.92      0.91       198
# WALKING_DOWNSTAIRS       0.92      0.89      0.91       145
#   WALKING_UPSTAIRS       0.94      0.94      0.94       177
#
#           accuracy                           0.82      1177
#          macro avg       0.83      0.83      0.83      1177
#       weighted avg       0.82      0.82      0.82      1177

# %%
# 성능 높여보기

# %% [markdown]
# ### (2) 알고리즘2 : XGBboost

# %%
from xgboost import XGBClassifier

model = XGBClassifier()
model.fit(x_train, y_train_l)

y_pred = model.predict(x_val)
print(accuracy_score(y_val_l, y_pred))
print(classification_report(y_val_l, y_pred))

fi = plot_feature_importance(model.feature_importances_, list(x_train))
for i in range(50, 301, 50):
    cols = fi['feature_names'].values[:i]
    temp_x = x_train[cols]
    rf = XGBClassifier()
    rf.fit(temp_x, y_train_l)
    print(f"{i} : {rf.score(x_val[cols], y_val_l)}")
# Out:
# 0.9923534409515717
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       231
#            1       0.98      0.99      0.99       200
#            2       1.00      0.98      0.99       226
#            3       0.99      0.98      0.99       198
#            4       0.99      0.99      0.99       145
#            5       0.99      1.00      0.99       177
#
#     accuracy                           0.99      1177
#    macro avg       0.99      0.99      0.99      1177
# weighted avg       0.99      0.99      0.99      1177
#
# 50 : 0.9821580288870009
# 100 : 0.9915038232795242
# 150 : 0.9932030586236194
# 200 : 0.9915038232795242
# 250 : 0.994052676295667
# 300 : 0.9923534409515717

# %%
# 변수 랜덤 20개 선택
from xgboost import XGBClassifier

model = XGBClassifier()
model.fit(x_train, y_train_l)

y_pred = model.predict(x_val)
print(accuracy_score(y_val_l, y_pred))
print(classification_report(y_val_l, y_pred))
# Out:
# 0.8538657604078165
#               precision    recall  f1-score   support
#
#            0       0.83      0.86      0.84       231
#            1       0.75      0.68      0.71       200
#            2       0.75      0.78      0.77       226
#            3       0.94      0.95      0.95       198
#            4       0.94      0.94      0.94       145
#            5       0.96      0.96      0.96       177
#
#     accuracy                           0.85      1177
#    macro avg       0.86      0.86      0.86      1177
# weighted avg       0.85      0.85      0.85      1177

# %%
# 성능 높여보기

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# 파라미터 선언
params = {'max_depth':range(1, 31)}  # 30개 선언

# 기본 모델 선언
xgb_cfi = XGBClassifier(random_state=42)

# Random Search 선언
  # cv=5
  # n_iter=20 / Grid Search 일 경우에는 n_iter만 빼고 나머지 그대로 사용
  # scoring='r2'
model = GridSearchCV(xgb_cfi,     # 기본 모델
                    params,        # 파라미터 범위
                    cv = 5,        # K-Fold 개수
                    scoring='accuracy',   # 평가지표
                    verbose=1
                    )

# 모델 학습
model.fit(x_train, y_train_l)

# 결과 확인
print(model.cv_results_['mean_test_score'])  # 수행 정보 중 평균 성능값들 출력
print('최적파라미터:', model.best_params_)    # 최적 파라미터
print('최고성능:', model.best_score_)         # 최고성능
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [0.73192823 0.78635087 0.8165399  0.81994099 0.8271696  0.82886721
#  0.8297185  0.82652972 0.83269473 0.83141859 0.83460601 0.83035612
#  0.83418342 0.8329084  0.83397088 0.83503358 0.8356721  0.83227011
#  0.83248287 0.83205757 0.83503493 0.8335458  0.83630791 0.83035747
#  0.83418206 0.8322692  0.83290682 0.83269428 0.83269428 0.83269428]
# 최적파라미터: {'max_depth': 23}
# 최고성능: 0.8363079114568024

# %%
from xgboost import XGBClassifier

xgb_clf = XGBClassifier()
xgb_clf.fit(x_train, y_train_l)

y_pred_clf = xgb_clf.predict(x_val)
print(accuracy_score(y_val_l, y_pred_clf))
print(classification_report(y_val_l, y_pred_clf))
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [03:19:26] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "mean_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 0.8181818181818182
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82       231
#            1       0.71      0.62      0.66       200
#            2       0.73      0.77      0.75       226
#            3       0.88      0.89      0.89       198
#            4       0.91      0.88      0.89       145
#            5       0.92      0.94      0.93       177
#
#     accuracy                           0.82      1177
#    macro avg       0.83      0.82      0.82      1177
# weighted avg       0.82      0.82      0.82      1177

# %% [markdown]
# ### (3) 알고리즘3 : Logistic

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(x_train_s, y_train)

y_pred = model.predict(x_val_s)
print(accuracy_score(y_val, y_pred))
print(classification_report(y_val, y_pred))

pfi = permutation_importance(model, x_val_s, y_val, n_repeats=1, scoring = 'accuracy', random_state=42)
fi = plot_feature_importance(pfi.importances_mean, list(x_train))
for i in range(50, 301, 50):
    cols = fi['feature_names'].values[:i]
    temp_x = x_train[cols]
    rf = LogisticRegression(max_iter=1000)
    rf.fit(temp_x, y_train)
    print(f"{i} : {rf.score(x_val[cols], y_val)}")
# Out:
# 0.9881053525913339
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       231
#            SITTING       0.95      0.99      0.97       200
#           STANDING       0.99      0.96      0.97       226
#            WALKING       1.00      0.99      1.00       198
# WALKING_DOWNSTAIRS       1.00      0.99      1.00       145
#   WALKING_UPSTAIRS       0.99      1.00      0.99       177
#
#           accuracy                           0.99      1177
#          macro avg       0.99      0.99      0.99      1177
#       weighted avg       0.99      0.99      0.99      1177
#
# 50 : 0.9651656754460493
# 100 : 0.9864061172472387
# 150 : 0.9872557349192863
# 200 : 0.9872557349192863
# 250 : 0.9906542056074766
# 300 : 0.989804587935429
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# 변수 랜덤 50개 선택
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(x_train_s, y_train)

y_pred = model.predict(x_val_s)
print(accuracy_score(y_val, y_pred))
print(classification_report(y_val, y_pred))
# Out:
# 0.6389124893797791
#                     precision    recall  f1-score   support
#
#             LAYING       0.58      0.71      0.64       231
#            SITTING       0.36      0.20      0.25       200
#           STANDING       0.55      0.65      0.60       226
#            WALKING       0.72      0.72      0.72       198
# WALKING_DOWNSTAIRS       0.74      0.74      0.74       145
#   WALKING_UPSTAIRS       0.84      0.86      0.85       177
#
#           accuracy                           0.64      1177
#          macro avg       0.63      0.65      0.63      1177
#       weighted avg       0.62      0.64      0.62      1177

# %% [markdown]
# ### (4) 알고리즘4 : SVM

# %%
# 변수 랜덤 50개 선택
from sklearn.svm import SVC

model = SVC()
model.fit(x_train_s, y_train)

y_pred = model.predict(x_val_s)
print(accuracy_score(y_val, y_pred))
print(classification_report(y_val, y_pred))
# Out:
# 0.7102803738317757
#                     precision    recall  f1-score   support
#
#             LAYING       0.62      0.80      0.70       231
#            SITTING       0.59      0.23      0.33       200
#           STANDING       0.60      0.74      0.66       226
#            WALKING       0.78      0.86      0.82       198
# WALKING_DOWNSTAIRS       0.88      0.79      0.83       145
#   WALKING_UPSTAIRS       0.89      0.87      0.88       177
#
#           accuracy                           0.71      1177
#          macro avg       0.73      0.71      0.70      1177
#       weighted avg       0.71      0.71      0.69      1177

# %% [markdown]
# ### (5) 딥러닝

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout, Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

# %%
model = Sequential([
    Input(shape=(x_train_s.shape[1])),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(1024, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(1024, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(6, activation='softmax'),
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_22 (Dense)            (None, 128)               2688
#
#  batch_normalization_18 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_18 (Dropout)        (None, 128)               0
#
#  dense_23 (Dense)            (None, 256)               33024
#
#  batch_normalization_19 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_19 (Dropout)        (None, 256)               0
#
#  dense_24 (Dense)            (None, 512)               131584
#
#  batch_normalization_20 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dropout_20 (Dropout)        (None, 512)               0
#
#  dense_25 (Dense)            (None, 1024)              525312
#
#  batch_normalization_21 (Ba  (None, 1024)              4096
#  tchNormalization)
#
#  dropout_21 (Dropout)        (None, 1024)              0
#
#  dense_26 (Dense)            (None, 1024)              1049600
#
#  batch_normalization_22 (Ba  (None, 1024)              4096
#  tchNormalization)
#
#  dropout_22 (Dropout)        (None, 1024)              0
#
#  dense_27 (Dense)            (None, 512)               524800
#
#  batch_normalization_23 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dropout_23 (Dropout)        (None, 512)               0
#
#  dense_28 (Dense)            (None, 256)               131328
#
#  batch_normalization_24 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_24 (Dropout)        (None, 256)               0
#
#  dense_29 (Dense)            (None, 128)               32896
#
#  batch_normalization_25 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_25 (Dropout)        (None, 128)               0
#
#  dense_30 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 2447366 (9.34 MB)
# Trainable params: 2439686 (9.31 MB)
# Non-trainable params: 7680 (30.00 KB)
# _________________________________________________________________

# %%
es = EarlyStopping(monitor='val_loss', patience=30, min_delta=0, verbose=1, restore_best_weights=True)

model.fit(x_train_s, y_train_l, verbose=1, epochs=200, callbacks=[es], validation_split=0.2)
# Out:
# Epoch 1/200
# 118/118 [==============================] - 12s 63ms/step - loss: 1.2639 - accuracy: 0.4993 - val_loss: 2.3069 - val_accuracy: 0.2253
# Epoch 2/200
# 118/118 [==============================] - 7s 57ms/step - loss: 0.9934 - accuracy: 0.5567 - val_loss: 2.1393 - val_accuracy: 0.2519
# Epoch 3/200
# 118/118 [==============================] - 7s 63ms/step - loss: 0.8917 - accuracy: 0.6088 - val_loss: 1.7789 - val_accuracy: 0.2901
# Epoch 4/200
# 118/118 [==============================] - 7s 57ms/step - loss: 0.8737 - accuracy: 0.6027 - val_loss: 0.9163 - val_accuracy: 0.5685
# Epoch 5/200
# 118/118 [==============================] - 7s 63ms/step - loss: 0.8278 - accuracy: 0.6240 - val_loss: 0.7212 - val_accuracy: 0.6865
# Epoch 6/200
# 118/118 [==============================] - 7s 62ms/step - loss: 0.8101 - accuracy: 0.6333 - val_loss: 0.6780 - val_accuracy: 0.6854
# Epoch 7/200
# 118/118 [==============================] - 8s 68ms/step - loss: 0.7940 - accuracy: 0.6362 - val_loss: 0.6961 - val_accuracy: 0.6716
# Epoch 8/200
# 118/118 [==============================] - 6s 51ms/step - loss: 0